# %%
import pandas as pd
samid = pd.read_csv("../Original_Datasets/Sam_ID.csv")
print(samid.head())
# Out:
# /var/folders/5r/xpmg4qd96tb_5pks_bkh8z9w0000gn/T/ipykernel_63832/1697197355.py:2: DtypeWarning: Columns (6,7,15,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   samid = pd.read_csv("../Original_Datasets/Sam_ID.csv")
#    SAM_ADDRESS_ID  BUILDING_ID  RELATIONSHIP_TYPE  FULL_ADDRESS STREET_NUMBER  \
# 0               1       100778                  1     6-10 A St          6-10
# 1               2       126344                  1       15 A St            15
# 2               4       100797                  1        7 A St             7
# 3              11       154909                  1       10 A St            10
# 4              16       141250                  1  172-174 A St       172-174
#
#    IS_RANGE RANGE_FROM RANGE_TO UNIT FULL_STREET_NAME  ...        X_COORD  \
# 0         1          6       10  NaN             A St  ...  757684.428458
# 1         0        NaN      NaN  NaN             A St  ...  757724.178379
# ...

# %%
samid["FULL_ADDRESS"] = samid["FULL_ADDRESS"].str.upper().str.strip()
sam_address_list = samid["FULL_ADDRESS"].dropna().tolist()

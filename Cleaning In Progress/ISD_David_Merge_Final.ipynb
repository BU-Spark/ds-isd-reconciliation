# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# # Current Registry

# %%
registry_df = pd.read_csv("current_rental_registrations_251001.csv")

# %%
registry_df = registry_df[["RegisteredAddress"]]

# %%
registry_df["formatted_address"] = registry_df["RegisteredAddress"].str.replace(r"\s+,", ",", regex=True)
registry_df["formatted_address"] = registry_df["formatted_address"].astype(str).str.upper().str.strip()
# Remove unit numbers before the first comma (e.g., " AVE 5," → " AVE,")
registry_df["formatted_address"] = registry_df["formatted_address"].str.replace(
    r"\s+\d+(?=,)", "", regex=True
).str.strip()

# %%
import re

def clean_units(address):
    # Match pattern: [street] [unit], [city], MA [ZIP]
    match = re.match(r"^(.*\b(?:ST|AV|AVE|RD|BLVD|PL|CT|DR|TER|WAY|LN|SQ|TE|CIR|PKWY|PLZ|HWY))\s+[A-Z0-9\-]+, (.+?, MA \d{5})$", address)
    if match:
        return f"{match.group(1)}, {match.group(2)}"
    return address

registry_df["formatted_address"] = registry_df["formatted_address"].apply(clean_units)

# %%
registry_df['formatted_address'].sample(30)
# Out:
# 24756             2016 COMMONWEALTH AV, BRIGHTON, MA 02135
# 37484                   24 MANLEY ST, DORCHESTER, MA 02122
# 29848                       17 FOLLEN ST, BOSTON, MA 02116
# 23491              244 SAVIN HILL AV, DORCHESTER, MA 02125
# 22363                  376 COMMERCIAL ST, BOSTON, MA 02109
# 36519               17 LEEDSVILLE ST, DORCHESTER, MA 02122
# 29257               15-17 FARRINGTON AV, ALLSTON, MA 02134
# 10003             12 W BELLFLOWER ST, DORCHESTER, MA 02125
# 11943            12 WESTMINSTER ST, MISSION HILL, MA 02120
# 25169                17 WENSLEY ST, MISSION HILL, MA 02120
# 38172                   38 MASCOT ST, DORCHESTER, MA 02124
# 25191    5 MAJOR MICHAEL J O'CONNOR WY, SOUTH BOSTON, M...
# 10660                 107 WARREN ST, CHARLESTOWN, MA 02129
# 34229                  270 HUNTINGTON AV, BOSTON, MA 02115
# 21191            7 SOUTHBOURNE RD, JAMAICA PLAIN, MA 02130
# 645                      34 E NEWTON ST, ROXBURY, MA 02118
# 28105                  42 EIGHTH ST, CHARLESTOWN, MA 02129
# 7396                  49 SOUTH ST, JAMAICA PLAIN, MA 02130
# 14616                      15 ALBION ST, ROXBURY, MA 02119
# 22156                    23 COLWELL AV, BRIGHTON, MA 02135
# 9216             159-161 TOWNSEND ST, DORCHESTER, MA 02121
# 34386                  316 HUNTINGTON AV, BOSTON, MA 02115
# 14285                153 LAKE SHORE RD, BRIGHTON, MA 02135
# 10440                    50 WALNUT PARK, ROXBURY, MA 02119
# 25559                   20-22 COPLEY ST, ROXBURY, MA 02119
# 27777                      11 DWIGHT ST, ROXBURY, MA 02118
# 2793                      68 PHILLIPS ST, BOSTON, MA 02114
# 35252                      107 JERSEY ST, BOSTON, MA 02215
# 22841                      39 WARREN ST, ROXBURY, MA 02119
# 2490                     8 PAYSON AV, DORCHESTER, MA 02125
# Name: formatted_address, dtype: object

# %% [markdown]
# # Assessor Dataset

# %%
assessment_df = pd.read_csv("fy2025-property-assessment-data_12_30_2024.csv", dtype={21: str}, low_memory=False)

# %%
assessment_df = assessment_df[["ST_NUM", "ST_NUM2","ST_NAME","ZIP_CODE","CITY"]]

# %%
def combine_street_numbers(row):
    try:
        st_num = str(int(float(row['ST_NUM']))) if pd.notnull(row['ST_NUM']) else ""
        st_num2 = str(int(float(row['ST_NUM2']))) if pd.notnull(row['ST_NUM2']) else ""
        return f"{st_num}-{st_num2}" if st_num and st_num2 else st_num
    except:
        return ""

assessment_df["ST_NUM_COMBINED"] = assessment_df.apply(combine_street_numbers, axis=1)
assessment_df["ZIP_CODE_CLEAN"] = assessment_df["ZIP_CODE"].astype(str).str.extract(r'(\d+)')[0].str.zfill(5)

assessment_df["ST_NAME_CLEAN"] = assessment_df["ST_NAME"].astype(str).str.replace(r'\bAVE\.', 'AV', regex=True)

assessment_df["formatted_address"] = (
    assessment_df["ST_NUM_COMBINED"].str.strip() + " " +
    assessment_df["ST_NAME_CLEAN"].astype(str).str.strip() + ", " +
    assessment_df["CITY"].astype(str).str.strip() + ", MA " +
    assessment_df["ZIP_CODE_CLEAN"]
).str.upper()
assessment_df["formatted_address"].dropna().unique()[:10]
# Out:
# array(['104 PUTNAM ST, EAST BOSTON, MA 02128',
#        '197 LEXINGTON ST, EAST BOSTON, MA 02128',
#        '199 LEXINGTON ST, EAST BOSTON, MA 02128',
#        '201 LEXINGTON ST, EAST BOSTON, MA 02128',
#        '203 LEXINGTON ST, EAST BOSTON, MA 02128',
#        '205-207 LEXINGTON ST, EAST BOSTON, MA 02128',
#        '209-211 LEXINGTON ST, EAST BOSTON, MA 02128',
#        '213 LEXINGTON ST, EAST BOSTON, MA 02128',
#        '215 LEXINGTON ST, EAST BOSTON, MA 02128',
#        '217 LEXINGTON ST, EAST BOSTON, MA 02128'], dtype=object)

# %%
assessment_df[["ST_NUM", "ST_NUM2", "ST_NAME", "CITY", "ZIP_CODE", "formatted_address"]].sample(50)
# Out:
#         ST_NUM  ST_NUM2               ST_NAME              CITY  ZIP_CODE  \
# 84677     33.0      NaN            Fenwood RD            BOSTON    2115.0
# 161763     NaN      NaN            BERWICK ST      WEST ROXBURY    2132.0
# 88675      1.0      NaN           THORNTON TE           ROXBURY    2119.0
# 40125     76.0      NaN       Gainsborough ST            BOSTON    2115.0
# 11144     35.0     37.0                ELM ST       CHARLESTOWN    2129.0
# 119388     8.0      NaN              THANE ST        DORCHESTER    2124.0
# 27221    240.0      NaN         Devonshire ST            BOSTON    2110.0
# 36892    301.0    319.0           COLUMBUS AV            BOSTON    2116.0
# 132716   335.0      NaN          WALK HILL ST        ROSLINDALE    2131.0
# 48775    141.0      NaN             Revere ST            BOSTON    2114.0
# 126185    23.0      NaN           BANFIELD AV          MATTAPAN    2126.0
# 164982  5170.0      NaN         Washington ST      WEST ROXBURY    2132.0
# 46380     51.0      NaN          MT VERNON ST            BOSTON    2108.0
# 32581   1313.0      NaN         Washington ST            BOSTON    2118.0
# 20899      NaN      NaN  ANTHONY R VALENTI WY            BOSTON    2114.0
# 104339    45.0      NaN        NIGHTINGALE ST        DORCHESTER    2124.0
# 74853    118.0    120.0             MARINE RD      SOUTH BOSTON    2127.0
# 57102    107.0      NaN             Jersey ST            BOSTON    2215.0
# 104256    31.0      NaN              ABBOT ST        DORCHESTER    2124.0
# 174809    44.0      NaN         LEAMINGTON RD          BRIGHTON    2135.0
# 11815    242.0      NaN        Bunker Hill ST       CHARLESTOWN    2129.0
# 61199    335.0      NaN           W SECOND ST      SOUTH BOSTON    2127.0
# 2871      21.0     23.0          Lexington ST       EAST BOSTON    2128.0
# 91060    114.0    120.0          BROOKSIDE AV     JAMAICA PLAIN    2130.0
# 83710    249.0      NaN            RUGGLES ST  ROXBURY CROSSING    2120.0
# 70917    205.0      NaN           W EIGHTH ST      SOUTH BOSTON    2127.0
# 151062    56.0      NaN            HILLOCK ST        ROSLINDALE    2131.0
# 38814     38.0      NaN         ST GERMAIN ST            BOSTON    2115.0
# 98849     22.0      NaN             JEROME ST        DORCHESTER    2125.0
# 139151  1420.0      NaN              RIVER ST         HYDE PARK    2136.0
# 22759     10.0      NaN            BOWDOIN ST            BOSTON    2114.0
# 170201   322.0      NaN             SUMMIT AV          BRIGHTON    2135.0
# 113305    12.0      NaN          PENHALLOW ST        DORCHESTER    2124.0
# 156383    21.0      NaN           CONISTON RD        ROSLINDALE    2131.0
# 181374    41.0     43.0    N CRESCENT CIRCUIT          BRIGHTON    2135.0
# 168613     NaN      NaN             RODNEY ST          BRIGHTON    2135.0
# 100670   426.0      NaN         SAVIN HILL AV        DORCHESTER    2125.0
# 160441     NaN      NaN            CARROLL ST      WEST ROXBURY    2132.0
# 42934      6.0      NaN            Melrose ST            BOSTON    2116.0
# 6143      20.0      NaN             Haynes ST       EAST BOSTON    2128.0
# 179557    44.0      NaN           CHAMPNEY ST          BRIGHTON    2135.0
# 85775     76.0      NaN           HILLSIDE ST  ROXBURY CROSSING    2120.0
# 120499    48.0     50.0            LINDSEY ST        DORCHESTER    2124.0
# 132558    66.0      NaN            MT HOPE ST        ROSLINDALE    2131.0
# 31253    109.0    119.0              Beach ST            BOSTON    2111.0
# 71189     18.0      NaN               WARD ST      SOUTH BOSTON    2127.0
# 51194    123.0      NaN       COMMONWEALTH AV            BOSTON    2116.0
# 48220     70.0      NaN            Brimmer ST            BOSTON    2108.0
# 9558      36.0      NaN             Morris ST       EAST BOSTON    2128.0
# 86710    107.0      NaN             BYNNER ST     JAMAICA PLAIN    2130.0
#
#                                     formatted_address
# 84677                 33 FENWOOD RD, BOSTON, MA 02115
# 161763             BERWICK ST, WEST ROXBURY, MA 02132
# 88675                1 THORNTON TE, ROXBURY, MA 02119
# 40125            76 GAINSBOROUGH ST, BOSTON, MA 02115
# 11144             35-37 ELM ST, CHARLESTOWN, MA 02129
# 119388               8 THANE ST, DORCHESTER, MA 02124
# 27221             240 DEVONSHIRE ST, BOSTON, MA 02110
# 36892           301-319 COLUMBUS AV, BOSTON, MA 02116
# 132716         335 WALK HILL ST, ROSLINDALE, MA 02131
# 48775                 141 REVERE ST, BOSTON, MA 02114
# 126185             23 BANFIELD AV, MATTAPAN, MA 02126
# 164982     5170 WASHINGTON ST, WEST ROXBURY, MA 02132
# 46380               51 MT VERNON ST, BOSTON, MA 02108
# 32581            1313 WASHINGTON ST, BOSTON, MA 02118
# 20899          ANTHONY R VALENTI WY, BOSTON, MA 02114
# 104339        45 NIGHTINGALE ST, DORCHESTER, MA 02124
# 74853       118-120 MARINE RD, SOUTH BOSTON, MA 02127
# 57102                 107 JERSEY ST, BOSTON, MA 02215
# 104256              31 ABBOT ST, DORCHESTER, MA 02124
# 174809           44 LEAMINGTON RD, BRIGHTON, MA 02135
# 11815       242 BUNKER HILL ST, CHARLESTOWN, MA 02129
# 61199         335 W SECOND ST, SOUTH BOSTON, MA 02127
# 2871        21-23 LEXINGTON ST, EAST BOSTON, MA 02128
# 91060   114-120 BROOKSIDE AV, JAMAICA PLAIN, MA 02130
# 83710      249 RUGGLES ST, ROXBURY CROSSING, MA 02120
# 70917         205 W EIGHTH ST, SOUTH BOSTON, MA 02127
# 151062            56 HILLOCK ST, ROSLINDALE, MA 02131
# 38814              38 ST GERMAIN ST, BOSTON, MA 02115
# 98849              22 JEROME ST, DORCHESTER, MA 02125
# 139151             1420 RIVER ST, HYDE PARK, MA 02136
# 22759                 10 BOWDOIN ST, BOSTON, MA 02114
# 170201              322 SUMMIT AV, BRIGHTON, MA 02135
# 113305          12 PENHALLOW ST, DORCHESTER, MA 02124
# 156383           21 CONISTON RD, ROSLINDALE, MA 02131
# 181374   41-43 N CRESCENT CIRCUIT, BRIGHTON, MA 02135
# 168613                  RODNEY ST, BRIGHTON, MA 02135
# 100670        426 SAVIN HILL AV, DORCHESTER, MA 02125
# 160441             CARROLL ST, WEST ROXBURY, MA 02132
# 42934                  6 MELROSE ST, BOSTON, MA 02116
# 6143              20 HAYNES ST, EAST BOSTON, MA 02128
# 179557             44 CHAMPNEY ST, BRIGHTON, MA 02135
# 85775      76 HILLSIDE ST, ROXBURY CROSSING, MA 02120
# 120499         48-50 LINDSEY ST, DORCHESTER, MA 02124
# 132558            66 MT HOPE ST, ROSLINDALE, MA 02131
# 31253              109-119 BEACH ST, BOSTON, MA 02111
# 71189              18 WARD ST, SOUTH BOSTON, MA 02127
# 51194           123 COMMONWEALTH AV, BOSTON, MA 02116
# 48220                 70 BRIMMER ST, BOSTON, MA 02108
# 9558              36 MORRIS ST, EAST BOSTON, MA 02128
# 86710          107 BYNNER ST, JAMAICA PLAIN, MA 02130

# %% [markdown]
# # Current vs Assessor MinHash

# %%
# STEP 0: Required Libraries
from datasketch import MinHash, MinHashLSH
import pandas as pd
import re

# STEP 1: Tokenizer + MinHash generator
def tokenize(address, ngram=3):
    address = re.sub(r'[^\w\s]', '', str(address).upper())
    return set(address[i:i+ngram] for i in range(len(address) - ngram + 1))

def create_minhash(tokens):
    m = MinHash(num_perm=128)
    for token in tokens:
        m.update(token.encode('utf8'))
    return m

# STEP 2: Extract house number
def extract_house_number(address):
    match = re.match(r"^(\d+)", str(address).strip())
    return int(match.group(1)) if match else None

# STEP 3: Safe MinHash with house number check
def safe_minhash_match(address, lsh_index):
    try:
        tokens = tokenize(address)
        input_num = extract_house_number(address)
        m = create_minhash(tokens)
        matches = lsh_index.query(m)
        for match_addr in matches:
            match_num = extract_house_number(match_addr)
            if input_num == match_num:
                return match_addr
        return None
    except:
        return None

# %%
# Make sure your registry address column is cleaned and ready
registered_addresses = registry_df["formatted_address"].dropna().unique().tolist()

# Build LSH index
lsh = MinHashLSH(threshold=0.8, num_perm=128)
for addr in registered_addresses:
    m = create_minhash(tokenize(addr))
    lsh.insert(addr, m)

# %%
assessment_df["minhash_strict"] = assessment_df["formatted_address"].apply(lambda x: safe_minhash_match(x, lsh))

# Filter unmatched = unregistered
unregistered_assessor_strict = assessment_df[assessment_df["minhash_strict"].isnull()]

# %%
matched_assessor = assessment_df[assessment_df["minhash_strict"].notnull()]
matched_assessor[["formatted_address", "minhash_strict"]].head(20)
# Out:
#                               formatted_address  \
# 1       197 LEXINGTON ST, EAST BOSTON, MA 02128
# 2       199 LEXINGTON ST, EAST BOSTON, MA 02128
# 4       203 LEXINGTON ST, EAST BOSTON, MA 02128
# 5   205-207 LEXINGTON ST, EAST BOSTON, MA 02128
# 6   209-211 LEXINGTON ST, EAST BOSTON, MA 02128
# 7       213 LEXINGTON ST, EAST BOSTON, MA 02128
# 8       215 LEXINGTON ST, EAST BOSTON, MA 02128
# 9       217 LEXINGTON ST, EAST BOSTON, MA 02128
# 10      217 LEXINGTON ST, EAST BOSTON, MA 02128
# 11      217 LEXINGTON ST, EAST BOSTON, MA 02128
# 12      217 LEXINGTON ST, EAST BOSTON, MA 02128
# 15      223 LEXINGTON ST, EAST BOSTON, MA 02128
# 19      237 LEXINGTON ST, EAST BOSTON, MA 02128
# 25      241 LEXINGTON ST, EAST BOSTON, MA 02128
# 26      241 LEXINGTON ST, EAST BOSTON, MA 02128
# 27      241 LEXINGTON ST, EAST BOSTON, MA 02128
# 28      241 LEXINGTON ST, EAST BOSTON, MA 02128
# 29      243 LEXINGTON ST, EAST BOSTON, MA 02128
# 30      243 LEXINGTON ST, EAST BOSTON, MA 02128
# 31      245 LEXINGTON ST, EAST BOSTON, MA 02128
#
#                                  minhash_strict
# 1       197 LEXINGTON ST, EAST BOSTON, MA 02128
# 2       199 LEXINGTON ST, EAST BOSTON, MA 02128
# 4       203 LEXINGTON ST, EAST BOSTON, MA 02128
# 5   205-207 LEXINGTON ST, EAST BOSTON, MA 02128
# 6       209 LEXINGTON ST, EAST BOSTON, MA 02128
# 7       213 LEXINGTON ST, EAST BOSTON, MA 02128
# 8      215 BENNINGTON ST, EAST BOSTON, MA 02128
# 9       217 LEXINGTON ST, EAST BOSTON, MA 02128
# 10      217 LEXINGTON ST, EAST BOSTON, MA 02128
# 11      217 LEXINGTON ST, EAST BOSTON, MA 02128
# 12      217 LEXINGTON ST, EAST BOSTON, MA 02128
# 15      223 LEXINGTON ST, EAST BOSTON, MA 02128
# 19      237 LEXINGTON ST, EAST BOSTON, MA 02128
# 25      241 LEXINGTON ST, EAST BOSTON, MA 02128
# 26      241 LEXINGTON ST, EAST BOSTON, MA 02128
# 27      241 LEXINGTON ST, EAST BOSTON, MA 02128
# 28      241 LEXINGTON ST, EAST BOSTON, MA 02128
# 29      243 LEXINGTON ST, EAST BOSTON, MA 02128
# 30      243 LEXINGTON ST, EAST BOSTON, MA 02128
# 31              245 BEACON ST, BOSTON, MA 02116

# %%
total_assessor = assessment_df["formatted_address"].notna().sum()
unregistered_assessor_strict_count = len(unregistered_assessor_strict)
percent_unregistered_assessor = round((unregistered_assessor_strict_count / total_assessor) * 100, 2)
print("🏠 Assessor Properties")
print(f"Total formatted addresses: {total_assessor}")
print(f"Unregistered addresses: {unregistered_assessor_strict_count}")
print(f"Percentage unregistered: {percent_unregistered_assessor}%")
# Out:
# 🏠 Assessor Properties
# Total formatted addresses: 183442
# Unregistered addresses: 127052
# Percentage unregistered: 69.26%

# %% [markdown]
# # 311 Dataset

# %%
service_df = pd.read_csv("dff4d804-5031-443a-8409-8344efd0e5c8.csv", low_memory=False)

# %%
service_df = service_df[["location"]]

# %%
# Known city/neighborhood names to catch multi-word places like "SOUTH BOSTON", "JAMAICA PLAIN"
boston_neighborhoods = [
    "SOUTH BOSTON", "EAST BOSTON", "JAMAICA PLAIN", "MATTAPAN", "ROXBURY", 
    "BRIGHTON", "CHARLESTOWN", "HYDE PARK", "DORCHESTER", "WEST ROXBURY", 
    "ALLSTON", "ROSLINDALE", "BACK BAY", "FENWAY", "MISSION HILL", "NORTH END",
    "SOUTH END", "CHINATOWN"
]

def format_location(location):
    try:
        parts = location.strip().split()
        if len(parts) < 4:
            return location.upper()

        zip_code = parts[-1]
        state = parts[-2]

        # Try 2-word city names first
        possible_city = " ".join(parts[-4:-2]).upper()
        if possible_city in boston_neighborhoods:
            city = possible_city
            street = " ".join(parts[:-4])
        else:
            # Fall back to 1-word city names
            city = parts[-3].upper()
            street = " ".join(parts[:-3])

        return f"{street}, {city}, {state} {zip_code}".upper()
    except:
        return ""
service_df["formatted_address"] = service_df["location"].astype(str).apply(format_location)

# Replace AVE (or AVE.) with AV in 311 formatted addresses
service_df["formatted_address"] = service_df["formatted_address"].str.replace(
    r"\bAVE\.?\b", "AV", regex=True
)


service_df["formatted_address"].sample(30)
# Out:
# 190955                      31 DUSTIN ST, ALLSTON, MA 02134
# 10746                      119 G ST, SOUTH BOSTON, MA 02127
# 209989    INTERSECTION OF MASSACHUSETTS AV & PEIRSON, ST...
# 129463                      9 OBIERNE PL, ROXBURY, MA 02119
# 201039              22 CHESTNUT AV, JAMAICA PLAIN, MA 02130
# 3718                  30 RICHFIELD ST, DORCHESTER, MA 02125
# 78065     INTERSECTION OF PLAYSTEAD RD & WALNUT ENTRANCE...
# 203297                     58-60 SALEM ST, BOSTON, MA 02113
# 98937                347 MAVERICK ST, EAST BOSTON, MA 02128
# 116955              2-4 NATIONAL ST, SOUTH BOSTON, MA 02127
# 217980                  574 CAMBRIDGE ST, ALLSTON, MA 02134
# 221837               16 BROOKFIELD ST, ROSLINDALE, MA 02131
# 157374                53 ROGERS PARK AV, BRIGHTON, MA 02135
# 90533               41 BAKERSFIELD ST, DORCHESTER, MA 02125
# 66068                          7 MINER ST, BOSTON, MA 02215
# 249517                  486 WASHINGTON ST, BOSTON, MA 02111
# 80267                590 CENTRE ST, JAMAICA PLAIN, MA 02130
# 253728              140 BAYSWATER ST, EAST BOSTON, MA 02128
# 203792                    65 HIGHLAND ST, ROXBURY, MA 02119
# 128424    INTERSECTION OF PUBLIC ALLEY NO. 415 & PUBLIC ...
# 63972               50-58 GAINSBOROUGH ST, BOSTON, MA 02115
# 219214                  476 WARREN ST, DORCHESTER, MA 02121
# 89203             172-196 NORTHAMPTON ST, ROXBURY, MA 02118
# 251680              627 E SECOND ST, SOUTH BOSTON, MA 02127
# 22249                      38 HOBART ST, BRIGHTON, MA 02135
# 151132    INTERSECTION OF BELGRAVIA PL & CHARTER, ST, BO...
# 201598              5 ROCKINGHAM AV, WEST ROXBURY, MA 02132
# 187037                     200 CHARLES ST, BOSTON, MA 02114
# 178009              532 E FOURTH ST, SOUTH BOSTON, MA 02127
# 83138     INTERSECTION OF COLUMBUS AV & DAVENPORT ST, MI...
# Name: formatted_address, dtype: object

# %% [markdown]
# # Current Vs 311 MinHash

# %%
# STEP 0: Required Libraries
from datasketch import MinHash, MinHashLSH
import pandas as pd
import re

# STEP 1: Tokenizer + MinHash generator
def tokenize(address, ngram=3):
    address = re.sub(r'[^\w\s]', '', str(address).upper())
    return set(address[i:i+ngram] for i in range(len(address) - ngram + 1))

def create_minhash(tokens):
    m = MinHash(num_perm=128)
    for token in tokens:
        m.update(token.encode('utf8'))
    return m

# STEP 2: Extract house number
def extract_house_number(address):
    match = re.match(r"^(\d+)", str(address).strip())
    return int(match.group(1)) if match else None

# STEP 3: Safe MinHash with house number check
def safe_minhash_match(address, lsh_index):
    try:
        tokens = tokenize(address)
        input_num = extract_house_number(address)
        m = create_minhash(tokens)
        matches = lsh_index.query(m)
        for match_addr in matches:
            match_num = extract_house_number(match_addr)
            if input_num == match_num:
                return match_addr
        return None
    except:
        return None

# %%
# Make sure your registry address column is cleaned and ready
registered_addresses = registry_df["formatted_address"].dropna().unique().tolist()

# Build LSH index
lsh = MinHashLSH(threshold=0.8, num_perm=128)
for addr in registered_addresses:
    m = create_minhash(tokenize(addr))
    lsh.insert(addr, m)

# %%
# Apply strict MinHash match with house number check
service_df["minhash_strict"] = service_df["formatted_address"].apply(lambda x: safe_minhash_match(x, lsh))

# Filter unmatched = unregistered
unregistered_311_strict = service_df[service_df["minhash_strict"].isnull()]

matched_311 = service_df[service_df["minhash_strict"].notnull()]

# Show side-by-side comparison
matched_311[["formatted_address", "minhash_strict"]].head(20)
# Out:
#                              formatted_address  \
# 2      416 BELGRADE AV, WEST ROXBURY, MA 02132
# 3         3 SAINT CHARLES ST, BOSTON, MA 02116
# 9          4 HARTWELL ST, DORCHESTER, MA 02121
# 10           32 FAIRFIELD ST, BOSTON, MA 02116
# 17      193 W NINTH ST, SOUTH BOSTON, MA 02127
# 19         40 MORRIS ST, EAST BOSTON, MA 02128
# 20             4 GILMER ST, MATTAPAN, MA 02126
# 25      394 MERIDIAN ST, EAST BOSTON, MA 02128
# 27       1200 WASHINGTON ST, ROXBURY, MA 02118
# 29          331 FANEUIL ST, BRIGHTON, MA 02135
# 32  5008 WASHINGTON ST, WEST ROXBURY, MA 02132
# 34         134 DRAPER ST, DORCHESTER, MA 02122
# 35        17 ENNIS RD, JAMAICA PLAIN, MA 02119
# 40           128 CHANDLER ST, BOSTON, MA 02116
# 43       45 W BROADWAY, SOUTH BOSTON, MA 02127
# 45            229 RIVER ST, MATTAPAN, MA 02126
# 50       57 SAINT GERMAIN ST, BOSTON, MA 02115
# 54     1566 TREMONT ST, MISSION HILL, MA 02120
# 55            28 ATKINS ST, BRIGHTON, MA 02135
# 56             27 BOWDOIN ST, BOSTON, MA 02114
#
#                                 minhash_strict
# 2      416 BELGRADE AV, WEST ROXBURY, MA 02132
# 3         3 SAINT CHARLES ST, BOSTON, MA 02116
# 9        4-6 HARTWELL ST, DORCHESTER, MA 02121
# 10           32 FAIRFIELD ST, BOSTON, MA 02116
# 17     193 W EIGHTH ST, SOUTH BOSTON, MA 02127
# 19         40 MORRIS ST, EAST BOSTON, MA 02128
# 20             4 GILMER ST, MATTAPAN, MA 02126
# 25      394 MERIDIAN ST, EAST BOSTON, MA 02128
# 27       1200 WASHINGTON ST, ROXBURY, MA 02118
# 29          331 FANEUIL ST, BRIGHTON, MA 02135
# 32  5008 WASHINGTON ST, WEST ROXBURY, MA 02132
# 34         134 DRAPER ST, DORCHESTER, MA 02122
# 35        17 ENNIS RD, JAMAICA PLAIN, MA 02119
# 40           128 CHANDLER ST, BOSTON, MA 02116
# 43       45 W BROADWAY, SOUTH BOSTON, MA 02127
# 45           229A RIVER ST, MATTAPAN, MA 02126
# 50       57 SAINT GERMAIN ST, BOSTON, MA 02115
# 54     1566 TREMONT ST, MISSION HILL, MA 02120
# 55            28 ATKINS ST, BRIGHTON, MA 02135
# 56             27 BOWDOIN ST, BOSTON, MA 02114

# %%
total_311 = service_df["formatted_address"].notna().sum()
unregistered_311_strict_count = len(unregistered_311_strict)
percent_unregistered_311 = round((unregistered_311_strict_count / total_311) * 100, 2)
print("📋 311 Service Requests")
print(f"Total formatted addresses: {total_311}")
print(f"Unregistered addresses: {unregistered_311_strict_count}")
print(f"Percentage unregistered: {percent_unregistered_311}%\n")
# Out:
# 📋 311 Service Requests
# Total formatted addresses: 282836
# Unregistered addresses: 220260
# Percentage unregistered: 77.88%

# %% [markdown]
# # Unregistered List Concat

# %%
# Recombine both full rows
combined_unregistered_df = pd.concat([unregistered_311_strict, unregistered_assessor_strict], ignore_index=True)

# Drop duplicate addresses (but only if truly identical)
combined_unregistered_df = combined_unregistered_df.drop_duplicates(subset=["formatted_address"])

print(f" Total unique unregistered addresses (combined): {len(combined_unregistered_df)}")


# Now your house numbers are preserved
print("\n Sample addresses:")
print(combined_unregistered_df["formatted_address"].head(10))
# Out:
#  Total unique unregistered addresses (combined): 105589
#
#  Sample addresses:
# 0          160-162 LIVERPOOL ST, EAST BOSTON, MA 02128
# 1             1660 DORCHESTER AV, DORCHESTER, MA 02122
# 2                   47 TORREY ST, DORCHESTER, MA 02124
# 3                  11 CLAXTON ST, ROSLINDALE, MA 02131
# 4     252-254 S HUNTINGTON AV, JAMAICA PLAIN, MA 02130
# 5                  39 RAMSDELL AV, HYDE PARK, MA 02136
# 6             84 BUNKER HILL ST, CHARLESTOWN, MA 02129
# 7    INTERSECTION OF ROWLEY ST & WORRELL, ST, DORCH...
# 8                  99 SHANDON RD, DORCHESTER, MA 02124
# 9                  150 THIRD AV, CHARLESTOWN, MA 02129
# Name: formatted_address, dtype: object

# %%
combined_unregistered_df = combined_unregistered_df["formatted_address"]
combined_unregistered_df.to_csv("combined_unregistered_addresses.csv", index=False)

# %% [markdown]
# # SAM_ID Match

# %%
import pandas as pd
from datasketch import MinHash, MinHashLSH
import re

# Load your datasets
unregistered_df = pd.read_csv("combined_unregistered_addresses.csv")
sam_df = pd.read_csv("live_street_address_management_sam_addresses.csv")

# Extract just house number + street name
def extract_street_only(address):
    try:
        return str(address).split(",")[0].strip().upper()
    except:
        return ""

unregistered_df["street_only"] = unregistered_df.iloc[:, 0].apply(extract_street_only)
sam_df["street_only"] = sam_df["FULL_ADDRESS"].astype(str).apply(extract_street_only)

# Tokenization and MinHash functions
def tokenize(text, ngram=3):
    text = re.sub(r'[^\w\s]', '', str(text).upper())
    return set(text[i:i+ngram] for i in range(len(text) - ngram + 1))

def create_minhash(tokens):
    m = MinHash(num_perm=128)
    for token in tokens:
        m.update(token.encode('utf8'))
    return m

# Build LSH index from SAM street-only addresses
lsh = MinHashLSH(threshold=0.8, num_perm=128)
for addr in sam_df["street_only"].dropna().unique():
    lsh.insert(addr, create_minhash(tokenize(addr)))

# Match each unregistered street address
def match_street_only(text):
    try:
        m = create_minhash(tokenize(text))
        results = lsh.query(m)
        return results[0] if results else None
    except:
        return None

unregistered_df["minhash_match"] = unregistered_df["street_only"].apply(match_street_only)

# Merge matched SAM ID back in
matched_df = unregistered_df.merge(
    sam_df[["street_only", "SAM_ADDRESS_ID", "FULL_ADDRESS"]],
    left_on="minhash_match",
    right_on="street_only",
    how="left"
)

# Total unregistered addresses
total_unregistered = len(unregistered_df)

# Matched rows (those that got a SAM ID)
matched_with_sam = matched_df["SAM_ADDRESS_ID"].notna().sum()

# Calculate percentage
percent_matched = round((matched_with_sam / total_unregistered) * 100, 2)

# Print results
print("📊 SAM ID Matching Summary")
print(f"- Total unregistered addresses: {total_unregistered}")
print(f"- Matched with SAM ID: {matched_with_sam}")
print(f"- Percentage matched: {percent_matched}%")
# Out:
# /var/folders/4h/gm1b6b155z73jqkthlx4bgv00000gn/T/ipykernel_91964/3324297159.py:7: DtypeWarning: Columns (6,7,15,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   sam_df = pd.read_csv("live_street_address_management_sam_addresses.csv")
# 📊 SAM ID Matching Summary
# - Total unregistered addresses: 105588
# - Matched with SAM ID: 90783
# - Percentage matched: 85.98%

# %%
matched_df = matched_df[["formatted_address", "SAM_ADDRESS_ID"]]

# %%
matched_df.to_csv("unregistered_with_sam_ids.csv", index=False)
print("✅ Done! Output saved to 'unregistered_with_sam_ids.csv'")
# Out:
# ✅ Done! Output saved to 'unregistered_with_sam_ids.csv'
